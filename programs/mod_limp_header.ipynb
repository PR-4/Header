# %%
import pandas as pd

# %%
entrada = input('Qual Variavel deseja limpar?')

if entrada == 'RT':
    f = list('RT.csv', 'GR.csv') 
    df = pd.read_csv(f'../inputs/7MRL16DRJS/{f}', sep = ';') 
    df.replace(' ', '',regex=True,inplace=True) # tira os espaços vazios
    df.replace('_', '',regex=True,inplace=True) # tira os underlines
    display(df)

if entrada == 'GR':
    f = 'GR.csv' 
    df = pd.read_csv(f'../inputs/7MRL16DRJS/{f}', sep = ';') 
    df.replace(' ', '',regex=True,inplace=True) # tira os espaços vazios
    df.replace('_', '',regex=True,inplace=True) # tira os underlines vazios
    display(df)

if entrada == 'CAL':
    f = 'CAL.csv' 
    df = pd.read_csv(f'../inputs/7MRL16DRJS/{f}', sep = ';') 
    df.replace(' ', '',regex=True,inplace=True) # tira os espaços vazios
    df.replace('_', '',regex=True,inplace=True) # tira os underlines vazios
    display(df)

if entrada == 'DT':
    f = 'DT.csv' 
    df = pd.read_csv(f'../inputs/7MRL16DRJS/{f}', sep = ';') 
    df.replace(' ', '',regex=True,inplace=True) # tira os espaços vazios
    df.replace('_', '',regex=True,inplace=True) # tira os underlines vazios
    display(df)

if entrada == 'PHI':
    f = 'PHI.csv' 
    df = pd.read_csv(f'../inputs/7MRL16DRJS/{f}', sep = ';') 
    df.replace(' ', '',regex=True,inplace=True) # tira os espaços vazios
    df.replace('_', '',regex=True,inplace=True) # tira os underlines vazios
    display(df)

if entrada == 'NPHI':
    f = 'NPHI.csv' 
    df = pd.read_csv(f'../inputs/7MRL16DRJS/{f}', sep = ';') 
    df.replace(' ', '',regex=True,inplace=True) # tira os espaços vazios
    df.replace('_', '',regex=True,inplace=True) # tira os underlines vazios
    display(df)

if entrada == 'RHOB':
    f = 'RHOB.csv' 
    df = pd.read_csv(f'../inputs/7MRL16DRJS/{f}', sep = ';') 
    df.replace(' ', '',regex=True,inplace=True) # tira os espaços vazios
    df.replace('_', '',regex=True,inplace=True) # tira os underlines vazios
    display(df)

if entrada == 'RT':
    f = 'RT.csv' 
    df = pd.read_csv(f'../inputs/7MRL16DRJS/{f}', sep = ';') 
    df.replace(' ', '',regex=True,inplace=True) # tira os espaços vazios
    df.replace('_', '',regex=True,inplace=True) # tira os underlines vazios
    display(df)

if entrada == 'VSH':
    f = 'VSH.csv' 
    df = pd.read_csv(f'../inputs/7MRL16DRJS/{f}', sep = ';') 
    df.replace(' ', '',regex=True,inplace=True) # tira os espaços vazios
    df.replace('_', '',regex=True,inplace=True) # tira os underlines vazios
    display(df)

if entrada == 'SW':
    f = 'SW.csv' 
    df = pd.read_csv(f'../inputs/7MRL16DRJS/{f}', sep = ';') 
    df.replace(' ', '',regex=True,inplace=True) # tira os espaços vazios
    df.replace('_', '',regex=True,inplace=True) # tira os underlines vazios
    display(df)


# irá salvar os dados modificados no dataframe em um novo arquivo
df.to_csv(f'../outputs/{f}', encoding = 'utf-8', index = False, sep = ';') 
print('Variável ' f'{entrada}' ' foi salva com sucesso')
