# %%
import pandas as pd

# %%
entrada = input('Qual Variavel deseja limpar?')

if entrada == 'RT':
    f = 'RT.csv' 
    df = pd.read_csv(f'../inputs/7MRL16DRJS/{f}', sep = ';') 
    df.replace(' ', '',regex=True,inplace=True) # tira os espaços vazios
    df.replace('_', '',regex=True,inplace=True) # tira os underlines vazios
    display(df)

if entrada == 'GR':
    f = 'GR.csv' 
    df = pd.read_csv(f'../inputs/7MRL16DRJS/{f}', sep = ';') 
    df.replace(' ', '',regex=True,inplace=True) # tira os espaços vazios
    df.replace('_', '',regex=True,inplace=True) # tira os underlines vazios
    display(df)

if entrada == 'CAL':
    f = 'CAL.csv' 
    df = pd.read_csv(f'../inputs/7MRL16DRJS/{f}', sep = ';') 
    df.replace(' ', '',regex=True,inplace=True) # tira os espaços vazios
    df.replace('_', '',regex=True,inplace=True) # tira os underlines vazios
    display(df)

if entrada == 'DT':
    f = 'DT.csv' 
    df = pd.read_csv(f'../inputs/7MRL16DRJS/{f}', sep = ';') 
    df.replace(' ', '',regex=True,inplace=True) # tira os espaços vazios
    df.replace('_', '',regex=True,inplace=True) # tira os underlines vazios
    display(df)

if entrada == 'PHI':
    f = 'PHI.csv' 
    df = pd.read_csv(f'../inputs/7MRL16DRJS/{f}', sep = ';') 
    df.replace(' ', '',regex=True,inplace=True) # tira os espaços vazios
    df.replace('_', '',regex=True,inplace=True) # tira os underlines vazios
    display(df)

if entrada == 'NPHI':
    f = 'NPHI.csv' 
    df = pd.read_csv(f'../inputs/7MRL16DRJS/{f}', sep = ';') 
    df.replace(' ', '',regex=True,inplace=True) # tira os espaços vazios
    df.replace('_', '',regex=True,inplace=True) # tira os underlines vazios
    display(df)

if entrada == 'RHOB':
    f = 'RHOB.csv' 
    df = pd.read_csv(f'../inputs/7MRL16DRJS/{f}', sep = ';') 
    df.replace(' ', '',regex=True,inplace=True) # tira os espaços vazios
    df.replace('_', '',regex=True,inplace=True) # tira os underlines vazios
    display(df)

if entrada == 'RT':
    f = 'RT.csv' 
    df = pd.read_csv(f'../inputs/7MRL16DRJS/{f}', sep = ';') 
    df.replace(' ', '',regex=True,inplace=True) # tira os espaços vazios
    df.replace('_', '',regex=True,inplace=True) # tira os underlines vazios
    display(df)

if entrada == 'VSH':
    f = 'VSH.csv' 
    df = pd.read_csv(f'../inputs/7MRL16DRJS/{f}', sep = ';') 
    df.replace(' ', '',regex=True,inplace=True) # tira os espaços vazios
    df.replace('_', '',regex=True,inplace=True) # tira os underlines vazios
    display(df)

if entrada == 'SW':
    f = 'SW.csv' 
    df = pd.read_csv(f'../inputs/7MRL16DRJS/{f}', sep = ';') 
    df.replace(' ', '',regex=True,inplace=True) # tira os espaços vazios
    df.replace('_', '',regex=True,inplace=True) # tira os underlines vazios
    display(df)


# irá salvar os dados modificados no dataframe em um novo arquivo
df.to_csv(f'../outputs/{f}', encoding = 'utf-8', index = False, sep = ';')
# Out:
#         wellName datasetName      DEPT      CALI
# 0            NaN         NaN         m        in
# 1     7MRL16DRJS  RECALL0061  2816,249     -9999
# 2     7MRL16DRJS  RECALL0061  2816,401  12,60721
# 3     7MRL16DRJS  RECALL0061  2816,553   12,6001
# 4     7MRL16DRJS  RECALL0061  2816,706  12,60036
# ...          ...         ...       ...       ...
# 7645  7MRL16DRJS  RECALL0091  3021,379     -9999
# 7646  7MRL16DRJS  RECALL0091  3021,531     -9999
# 7647  7MRL16DRJS  RECALL0091  3021,684     -9999
# 7648  7MRL16DRJS  RECALL0091  3021,836     -9999
# 7649  7MRL16DRJS  RECALL0091  3021,988     -9999
#
# [7650 rows x 4 columns]
